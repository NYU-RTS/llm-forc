# %%
import os
import json
import random

from rich.console import Console
from rich.markdown import Markdown
from portkey_ai import Portkey

portkey = Portkey(
    base_url="https://ai-gateway.apps.cloud.rt.nyu.edu/v1/",
    api_key=os.getenv("PORTKEY_API_KEY"),
)

# %% [markdown]
# #### Define a python function and specification for passing it to an LLM

# %%
def roll_dice(N: int) -> int:
    """Roll an N sided die"""
    return random.randint(1,N)

tools = [
    {
        "type": "function",
        "name": "roll_dice",
        "description": "Roll the special N sided dice and return the result",
        "parameters": {
            "type": "object",
             "properties": {
                 "num_sides": {
                    "type": "integer",
                     "description": "Number of sides for the die to roll"
                }
              },
              "required": ["num_sides"]
        }
    }
]

available_tools = {"roll_dice":roll_dice}

# %% [markdown]
# #### Initnal user prompt

# %%
messages = [
        {"role": "user", "content": "Roll a 10 sided die and check if the dice roll was valid. Explain your reasoning."}
]

# %%
response = portkey.responses.create(
    model="@vertexai/gemini-3.5-flash",
    input=messages,
    tools=tools,
)

messages.extend(response.output)
print(response.output_text)

# %% [markdown]
# ### Extract the request from the LLM to call the tool and the argument to the tool

# %%
response.output
# Out:
# [ResponseFunctionToolCall(arguments='{"num_sides":10}', call_id='call_l38M88Up4bBKgxsU9ZshNVcK', name='roll_dice', type='function_call', id='fc_1fa5cd13-13c2-4b66-9937-7907c60fc118', namespace=None, status='completed')]

# %%
response.output[0].type
# Out:
# 'function_call'

# %%
function_to_call = available_tools[response.output[0].name]

# %%
dice_sides_to_roll = json.loads(response.output[0].arguments)["num_sides"]

# %%
dice_roll_result = function_to_call(dice_sides_to_roll)

# %% [markdown]
# ### Prepare a message to send to the LLM with the results of the tool call

# %%
tool_call_result = ({
    "type": "function_call_output",
    "call_id": response.output[0].call_id,
    "output": json.dumps(dice_roll_result)

})

# %%
messages.append(tool_call_result)

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Roll a 10 sided die and check if the dice roll was valid. Explain your reasoning.'},
#  ResponseFunctionToolCall(arguments='{"num_sides":10}', call_id='call_l38M88Up4bBKgxsU9ZshNVcK', name='roll_dice', type='function_call', id='fc_1fa5cd13-13c2-4b66-9937-7907c60fc118', namespace=None, status='completed'),
#  {'type': 'function_call_output',
#   'call_id': 'call_l38M88Up4bBKgxsU9ZshNVcK',
#   'output': '4'}]

# %% [markdown]
# ### Pass all the messages, the initial prompt, the first response from the LLM requesting tool use and finally the result of the tool use!

# %%
response = portkey.responses.create(
    model="@vertexai/gemini-3.5-flash",
    input=messages,
    tools=tools,
)

console = Console()
console.print(Markdown(response.output_text))
# Out:
# The result of rolling the 10-sided die is 4.
#
# Reasoning for validity:
#
#  1 Range Check: A standard 10-sided die (d10) has faces numbered from 1 to 10. The result obtained is 4, which
#    falls within this valid range ($1 \le 4 \le 10$).
#  2 Integer Check: Dice rolls must result in whole numbers (integers). The result is 4, which is an integer.
#
# Therefore, the dice roll is valid.
