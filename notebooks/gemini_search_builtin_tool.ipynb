# %%
import os
from portkey_ai import Portkey
from IPython.display import display, Markdown

portkey = Portkey(
    base_url="https://ai-gateway.apps.cloud.rt.nyu.edu/v1/",
    api_key=os.getenv("PORTKEY_API_KEY"),
)

# %% [markdown]
# ### Run the prompt without the tool

# %%
response = portkey.responses.create(
    model="@vertexai/gemini-2.5-flash",
    input="Tell me about the latest HPC cluster at NYU",
    max_output_tokens=8196,
)

display(Markdown(response.output_text))
# Out:
# The flagship general-purpose HPC cluster at NYU, and thus its "latest" in terms of continuous development and primary use, is **Greene**.
#
# Greene was launched in 2020 as the successor to the Prince cluster and has been continuously expanded and upgraded since then. It's designed to support a wide range of computational research needs across all NYU schools and departments.
#
# Here are some key characteristics of the Greene cluster:
#
# *   **Name:** Greene (named after Washington Square Park's historic Greene Street)
# *   **Purpose:** General-purpose high-performance computing, including large-scale simulations, data analysis, artificial intelligence (AI), machine learning (ML), and big data processing.
# *   **Architecture:** It's a hybrid CPU/GPU cluster, reflecting the growing demand for accelerated computing.
# *   **Processors (CPUs):** Primarily utilizes Intel Xeon Scalable processors (various generations, such as Ice Lake and Sapphire Rapids in newer expansions), offering high core counts and memory bandwidth per node.
# *   **Accelerators (GPUs):** Features a significant number of NVIDIA GPUs, predominantly NVIDIA A100 Tensor Core GPUs, which are crucial for AI/ML workloads and highly parallel scientific computations.
# *   **Interconnect:** Uses high-speed, low-latency interconnects like HDR InfiniBand to ensure rapid communication between nodes, essential for parallel applications.
# *   **Storage:** Backed by a high-performance parallel file system (like IBM Spectrum Scale/GPFS) providing vast storage capacity and high I/O throughput for large datasets.
# *   **Job Scheduler:** Employs Slurm, a widely used open-source workload manager.
# *   **Software Environment:** Provides a comprehensive software environment with compilers, libraries (e.g., MPI, CUDA), scientific applications, and deep learning frameworks (TensorFlow, PyTorch, etc.) accessible via modules.
# *   **Scale:** While specific numbers change with continuous upgrades, it typically comprises hundreds of compute nodes, thousands of CPU cores, and hundreds of powerful GPUs.
#
# **Key takeaway:** When people refer to the "latest" or main HPC cluster at NYU, they are almost certainly referring to **Greene**. It represents NYU's commitment to providing cutting-edge computational resources for its researchers.
#
# For the most up-to-date and detailed specifications, it's always best to check the official NYU High Performance Computing website: **hpc.nyu.edu**.

# %% [markdown]
# ### Run the prompt with the tool

# %%
response = portkey.responses.create(
    model="@vertexai/gemini-2.5-flash",
    tools=[{"type": "function", "name": "google_search"}],
    input="Tell me about the latest HPC cluster at NYU",
    max_output_tokens=8196,
)

display(Markdown(response.output_text))
# Out:
# NYU's latest high-performance computing (HPC) cluster is named **Torch**, unveiled in October 2025. It represents a significant upgrade from its predecessor, Greene, being five times more powerful.
#
# Torch is positioned as the most powerful supercomputer in New York State and one of the most powerful in higher education nationally. It is capable of performing approximately 11 quadrillion (11 x 10^15) calculations per second. Beyond its computational prowess, Torch is also designed with sustainability in mind, ranking No. 40 on the Top Green 500, a global list of the most sustainable supercomputers, thanks to its advanced liquid cooling system.
#
# Prior to Torch, NYU's flagship HPC cluster was **Greene**, which came online in 2020. Greene was noted as the most powerful supercomputer in the New York metropolitan area and among the top ten most powerful in higher education. It also featured water-cooled CPU nodes using Lenovo's Neptune liquid cooling technology, contributing to its energy efficiency and a No. 50 ranking on the Top Green 500 list in 2020. The Greene cluster has a total of 32,000 CPU processing cores and 145 terabytes of RAM, with an overall performance exceeding 4 petaflops. It includes a significant number of GPUs, with 292 NVIDIA RTX8000 GPUs and 40 V100 GPUs across various compute nodes. The "Hudson" HPC/AI cluster was incorporated into Greene in April 2023.
