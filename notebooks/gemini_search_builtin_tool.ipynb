# %%
import os
from portkey_ai import Portkey
from IPython.display import display, Markdown

portkey = Portkey(
    base_url="https://ai-gateway.apps.cloud.rt.nyu.edu/v1/",
    api_key=os.getenv("PORTKEY_API_KEY"),
)

# %% [markdown]
# ### Run the prompt without the tool

# %%
response = portkey.responses.create(
    model="@vertexai/gemini-2.5-flash",
    input="Tell me about the latest HPC cluster at NYU",
    max_output_tokens=8196,
)

display(Markdown(response.output_text))
# Out:
# The primary and latest general-purpose High-Performance Computing (HPC) cluster at NYU, managed by NYU IT, is named **Greene**.
#
# Greene was deployed to significantly expand NYU's computational resources, succeeding the previous primary cluster, Prince. It's designed to serve the diverse research needs of faculty, researchers, and students across various scientific and academic disciplines.
#
# Here are some key features and aspects of the Greene cluster:
#
# 1.  **Name:** Greene
# 2.  **Deployment:** It was deployed in phases, starting around 2020-2021, and has been continuously expanded and updated since.
# 3.  **Purpose:** General-purpose scientific computing, data analysis, machine learning, simulations, and other computationally intensive tasks.
# 4.  **Key Specifications (as of typical general knowledge, exact specs can evolve):**
#     *   **CPU Nodes:** A substantial number of CPU-only nodes, typically featuring modern Intel Xeon Gold or Platinum processors with high core counts (e.g., 20-64 cores per node) and significant RAM (e.g., 192GB, 384GB, 768GB, and even 1.5TB for high-memory nodes).
#     *   **GPU Nodes:** A significant number of nodes equipped with powerful NVIDIA GPUs, primarily A100 Tensor Core GPUs (often with 40GB or 80GB of memory per GPU), for accelerating AI/ML, molecular dynamics, and other GPU-intensive workloads.
#     *   **Interconnect:** A high-speed, low-latency InfiniBand network (often HDR InfiniBand) connecting all nodes, crucial for parallel applications.
#     *   **Storage:** A large, high-performance parallel file system (e.g., Lustre) providing petabytes of storage capacity with high throughput for handling large datasets.
#     *   **Operating System:** Typically runs a Linux-based operating system (e.g., CentOS or Rocky Linux).
#     *   **Job Scheduler:** Utilizes the Slurm Workload Manager for managing and scheduling jobs across the cluster.
# 5.  **Software Environment:** Greene provides a rich software environment, including:
#     *   Various compilers (GCC, Intel OneAPI)
#     *   Scientific libraries (MPI, MKL, CUDA, etc.)
#     *   Domain-specific applications (e.g., VASP, GROMACS, LAMMPS, MATLAB, R, Python distributions with scientific packages).
#     *   Module system (Lmod) for managing software versions.
# 6.  **Access:** Available to NYU faculty, researchers, and students. Users typically need to request an account and are often allocated a certain amount of compute time and storage based on their research needs.
# 7.  **Support:** NYU IT's High Performance Computing team provides extensive support, including documentation, training, and direct assistance to users.
#
# Greene represents a significant investment by NYU in its research infrastructure, providing cutting-edge computational power to support groundbreaking work across a wide array of disciplines, from astrophysics and genomics to finance and digital humanities.
#
# For the most up-to-date and detailed information, including specific technical specifications, user guides, and access request forms, you should always refer to the official NYU IT High Performance Computing website.

# %% [markdown]
# ### Run the prompt with the tool

# %%
response = portkey.responses.create(
    model="@vertexai/gemini-2.5-flash",
    tools=[{"type": "function", "name": "google_search"}],
    input="Tell me about the latest HPC cluster at NYU",
    max_output_tokens=8196,
)

display(Markdown(response.output_text))
# Out:
# NYU unveiled its latest High-Performance Computing (HPC) cluster, named "Torch," on October 9, 2025. Torch is currently the most powerful supercomputer in New York State and ranks among the most powerful in higher education nationally.
#
# Named after the university's iconic logo, Torch is a significant upgrade, boasting five times the processing power of NYU's previous supercomputer, Greene, which came online in 2020. Torch is capable of performing approximately 11 quadrillion (11 x 10^15) calculations per second.
#
# Beyond its raw power, Torch is also recognized for its sustainability, ranking No. 40 on the Top Green 500, a global list of the most sustainable supercomputers. This is largely due to its advanced liquid cooling system. The introduction of Torch is intended to substantially increase NYU's computational capacity, supporting the university's growing prominence in research across various disciplines such as neuroscience, virtual, and mixed reality. It is expected to empower researchers to undertake projects previously not possible.
